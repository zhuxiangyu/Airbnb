# %%
import pandas as pd
df=pd.read_csv('listings.csv')
df.head(5)
calculated_host_listings_count
review_scores_value
review_scores_communication
calculated_host_listings_count_shared_rooms
reviews_per_month
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  11156  https://www.airbnb.com/rooms/11156  20200910023158   2020-09-11
# 1  12351  https://www.airbnb.com/rooms/12351  20200910023158   2020-09-11
# 2  14250  https://www.airbnb.com/rooms/14250  20200910023158   2020-09-11
# 3  15253  https://www.airbnb.com/rooms/15253  20200910023158   2020-09-11
# 4  44545  https://www.airbnb.com/rooms/44545  20200910023158   2020-09-11
#
#                                                 name  \
# 0                               An Oasis in the City
# 1                  Sydney City & Harbour at the door
# 2                                Manly Harbour House
# 3  Unique Designer Rooftop Apartment in City Loca...
# 4             Sunny Darlinghurst Warehouse Apartment
#
#                                          description  \
# 0  Very central to the city which can be reached ...
# 1  Come stay with Vinh & Stuart (Awarded as one o...
# ...

# %%
#At this stage, what attracts me is to understand, which factor will contribute to a higher customer satisfaction when they choose Airbnb Listing?
# so what I need is the 
# coolumn names and their sample data?
